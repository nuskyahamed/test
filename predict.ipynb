# %%
# a. Load data into working environment
import pandas as pd

# Assuming your CSV file is named 'house_prices.csv'
file_path = 'house_prices.csv'
data = pd.read_csv(file_path)

# b. Visualize data in a table format
print("Table format of the data:")
print(data.head())

# c. If there are any unusable columns, drop them
# For example, if there are columns that are not relevant or contain a lot of missing values
# You may need to customize this based on your dataset
# Example: data = data.drop(['unusable_column1', 'unusable_column2'], axis=1)

# d. Do one-hot encoding to required data columns
# Assuming you want to one-hot encode a categorical column named 'category_column'
data = pd.get_dummies(data, columns=['category_column'])

# Assuming 'area' is your X and 'house_price' is your Y
X = data[['area']]  # You can select other columns as needed
y = data['house_price']

# e. Design a model
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# f. Fit the model
model.fit(X, y)

# g. Predict house price for a new input data
# Assuming you have new data in a DataFrame named 'new_data'
new_data = pd.DataFrame({'area': [1000, 1200, 1500]})  # Example new data

# Predict house prices for the new data
predictions = model.predict(new_data)

print("Predicted house prices for the new data:")
print(predictions)

# h. Find accuracy of your model
# Linear Regression doesn't have accuracy like classifiers, but you can evaluate using metrics like Mean Squared Error (MSE)
from sklearn.metrics import mean_squared_error

# Assuming you have test data
# Example: X_test, y_test = ...

# Make predictions on the test set
y_pred = model.predict(X_test)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("/content/drive/MyDrive/homeprices_q2_dataset.csv")

# %%
print(data)

# %%
data_encoded = pd.get_dummies(data, columns=['town'])
print(data_encoded)

# %%
# Create the model
model = LinearRegression()

# %%
# Separate the features (X) and target variable (Y)
X = data_encoded.drop('price', axis=1)
Y = data_encoded['price']

# Fit the model to the data
model.fit(X, Y)

# %%
# Define a new input data with matching feature columns in the correct order
new_data = pd.DataFrame({
    'town_Pave' :[0],
    'town_monroe township': [0],
    'town_robinsville': [0],
    'town_west windsor': [1],
    'area': [400]
})

# Reorder the columns to match the feature order during model fitting
new_data = new_data[X.columns]

# Perform prediction using the trained model
predicted_price = model.predict(new_data)
print("Predicted house price:", predicted_price)

# %%
# Separate the features (X) and target variable (Y) for evaluation
X_eval = data_encoded.drop('price', axis=1)
Y_eval = data_encoded['price']

# Predict the house prices using the trained model
predicted_prices = model.predict(X_eval)

# Calculate R-squared
r_squared = r2_score(Y_eval, predicted_prices)
print("Accuracy", r_squared)
